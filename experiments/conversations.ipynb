# %%
from langchain_google_genai import ChatGoogleGenerativeAI
GENAI_MODEL = "gemini-2.5-flash"
GENAI_MODEL = "gemini-2.5-flash-lite" #overrite

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
llm = ChatGoogleGenerativeAI(
    model=GENAI_MODEL,
    temperature=0.3,
)

# %%
#test
response = llm.invoke("hey , what model are u based on")
print(response.content)
# Out:
# I am a large language model, trained by Google.

# %%
GENAI_MODEL
# Out:
# 'gemini-2.5-flash'

# %%
from langchain.chat_models import init_chat_model
model = init_chat_model(f"google_genai:{GENAI_MODEL}")

# %%
response = model.invoke("hey , what model are u based on")
print(response)
# Out:
# content='I am a large language model, trained by Google.' additional_kwargs={} response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'} id='lc_run--933310cc-8ce8-49f0-a6e7-84585cabbf87-0' usage_metadata={'input_tokens': 9, 'output_tokens': 11, 'total_tokens': 20, 'input_token_details': {'cache_read': 0}}

# %% [markdown]
# ### observation,
# ##### here we have 2 oprions , using google genai wrapper or using langchain wrapper(which is a new update to langchain)
#
# ##### we will be using the new wrapper

# %%
from langchain.chains import ConversationChain
from langchain.memory import ConversationBufferMemory
